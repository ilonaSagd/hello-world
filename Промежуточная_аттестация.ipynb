# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
df_dataset_sk = pd.read_csv('https://raw.githubusercontent.com/ilonaSagd/AIilona/main/dataset_tk.csv')
df_dataset_sk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         503 non-null    object
#  1   Punjab             503 non-null    float64
#  2   Haryana            503 non-null    float64
#  3   Rajasthan          503 non-null    float64
#  4   Delhi              503 non-null    float64
#  5   UP                 503 non-null    float64
#  6   Uttarakhand        503 non-null    float64
#  7   HP                 503 non-null    float64
#  8   J&K                503 non-null    float64
#  9   Chandigarh         503 non-null    float64
#  10  Chhattisgarh       503 non-null    float64
#  11  Gujarat            503 non-null    float64
#  12  MP                 503 non-null    float64
#  13  Maharashtra        503 non-null    float64
#  14  Goa                503 non-null    float64
# ...

# %%
#проверяем пропуски
import numpy as np
path = r'https://raw.githubusercontent.com/ilonaSagd/AIilona/main/dataset_tk.csv'
df = pd.read_csv(path)
print('Количество пропусков по полям:\n' + str(df.isnull().sum()))
print('Всего пропусков: ' + str(df.isnull().sum().sum()))
# Out:
# Количество пропусков по полям:
# Unnamed: 0           0
# Punjab               0
# Haryana              0
# Rajasthan            0
# Delhi                0
# UP                   0
# Uttarakhand          0
# HP                   0
# J&K                  0
# Chandigarh           0
# Chhattisgarh         0
# Gujarat              0
# MP                   0
# Maharashtra          0
# Goa                  0
# DNH                  0
# Andhra Pradesh       0
# Telangana            0
# Karnataka            0
# Kerala               0
# Tamil Nadu           0
# Pondy                0
# Bihar                0
# Jharkhand            0
# Odisha               0
# West Bengal          0
# Sikkim               0
# Arunachal Pradesh    0
# Assam                0
# Manipur              0
# Meghalaya            0
# Mizoram              0
# Nagaland             0
# Tripura              0
# dtype: int64
# Всего пропусков: 0

# %%
#определяем максимум и минимум потребляемой электронергии по городам
max_val = df_dataset_sk.max()
min_val = df_dataset_sk.min()
print('Максимальные занчения:\n' + str(max_val) +
  '\n\nМинимальные значения:\n' + str(min_val))
# Out:
# Максимальные занчения:
# Unnamed: 0           31/12/2019 00:00:00
# Punjab                             300.0
# Haryana                            237.2
# Rajasthan                          278.0
# Delhi                              147.1
# UP                                 471.8
# Uttarakhand                         53.2
# HP                                  34.0
# J&K                                 54.2
# Chandigarh                           7.4
# Chhattisgarh                       111.6
# Gujarat                            400.8
# MP                                 272.3
# Maharashtra                        522.1
# Goa                                 14.0
# DNH                                 19.5
# Andhra Pradesh                     205.1
# Telangana                          256.2
# Karnataka                          273.3
# Kerala                              89.4
# Tamil Nadu                         365.4
# Pondy                                9.7
# ...

# %%
#определяем уникальное значение потребляемой электроэнергии
df_dataset_sk.nunique ()
# Out:
# Unnamed: 0           498
# Punjab               394
# Haryana              388
# Rajasthan            379
# Delhi                337
# UP                   444
# Uttarakhand          203
# HP                   138
# J&K                  172
# Chandigarh            48
# Chhattisgarh         272
# Gujarat              403
# MP                   407
# Maharashtra          422
# Goa                   69
# DNH                   82
# Andhra Pradesh       318
# Telangana            387
# Karnataka            393
# Kerala               231
# Tamil Nadu           411
# Pondy                 56
# Bihar                297
# Jharkhand             94
# Odisha               283
# West Bengal          365
# Sikkim                22
# Arunachal Pradesh     17
# Assam                168
# Manipur               16
# Meghalaya             36
# Mizoram               11
# Nagaland              12
# Tripura               38
# dtype: int64

# %%
df_dataset_sk.describe()
# Out:
#            Punjab     Haryana   Rajasthan       Delhi          UP  \
# count  503.000000  503.000000  503.000000  503.000000  503.000000
# mean   141.145527  138.333598  218.443340   83.380716  314.036382
# std     56.977361   38.106593   27.421615   25.915357   66.516960
# min     56.100000   64.800000  105.800000   41.800000  186.800000
# 25%    104.000000  114.800000  205.800000   63.500000  263.650000
# 50%    118.300000  126.800000  222.900000   72.700000  290.000000
# 75%    162.500000  158.100000  237.600000  105.800000  370.550000
# max    300.000000  237.200000  278.000000  147.100000  471.800000
#
#        Uttarakhand          HP         J&K  Chandigarh  Chhattisgarh  ...  \
# count   503.000000  503.000000  503.000000  503.000000    503.000000  ...
# mean     36.157058   26.568191   44.264016    4.141551     83.877137  ...
# std       6.705108    4.807040    4.769391    1.143422     10.130427  ...
# min      16.800000   11.800000   17.800000    2.200000     37.200000  ...
# ...

# %%
#проверим значения по городу Delphi
hist = df_dataset_sk['Delhi'].hist(alpha = 0.5)

# %%
df.head()
# Out:
#             Unnamed: 0  Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand  \
# 0  02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9         40.7
# 1  03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8         39.3
# 2  04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7         38.1
# 3  05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0         39.2
# 4  06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8         39.2
#
#      HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0  30.0  52.5         5.0  ...    70.2        108.2     2.0
# 1  30.1  54.1         4.9  ...    67.9        110.2     1.9
# 2  30.1  53.2         4.8  ...    66.3        106.8     1.7
# 3  30.2  51.5         4.3  ...    65.8        107.0     2.0
# 4  31.0  53.2         4.3  ...    62.9        106.4     2.0
#
#    Arunachal Pradesh  Assam  Manipur  Meghalaya  Mizoram  Nagaland  Tripura
# ...

# %%
#выгружаем колонки
columns = list(df.columns)
columns
# Out:
# ['Unnamed: 0',
#  'Punjab',
#  'Haryana',
#  'Rajasthan',
#  'Delhi',
#  'UP',
#  'Uttarakhand',
#  'HP',
#  'J&K',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Gujarat',
#  'MP',
#  'Maharashtra',
#  'Goa',
#  'DNH',
#  'Andhra Pradesh',
#  'Telangana',
#  'Karnataka',
#  'Kerala',
#  'Tamil Nadu',
#  'Pondy',
#  'Bihar',
#  'Jharkhand',
#  'Odisha',
#  'West Bengal',
#  'Sikkim',
#  'Arunachal Pradesh',
#  'Assam',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Tripura']

# %%
#заменяем колонку Unnamed на Date
df.rename(columns={'Unnamed: 0':'Date'},inplace=True)
columns = list(df.columns)
columns
# Out:
# ['Date',
#  'Punjab',
#  'Haryana',
#  'Rajasthan',
#  'Delhi',
#  'UP',
#  'Uttarakhand',
#  'HP',
#  'J&K',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Gujarat',
#  'MP',
#  'Maharashtra',
#  'Goa',
#  'DNH',
#  'Andhra Pradesh',
#  'Telangana',
#  'Karnataka',
#  'Kerala',
#  'Tamil Nadu',
#  'Pondy',
#  'Bihar',
#  'Jharkhand',
#  'Odisha',
#  'West Bengal',
#  'Sikkim',
#  'Arunachal Pradesh',
#  'Assam',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Tripura']

# %%
df
# Out:
#                     Date  Punjab  Haryana  Rajasthan  Delhi     UP  \
# 0    02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9
# 1    03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8
# 2    04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7
# 3    05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0
# 4    06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8
# ..                   ...     ...      ...        ...    ...    ...
# 498  01/12/2020 00:00:00   130.8    126.0      220.4   77.3  322.8
# 499  02/12/2020 00:00:00   129.4    127.3      218.4   81.3  331.4
# 500  03/12/2020 00:00:00   132.1    129.7      205.6   85.6  336.7
# 501  04/12/2020 00:00:00   132.1    128.4      207.0   83.9  334.6
# 502  05/12/2020 00:00:00   120.4    111.2      201.4   83.6  287.3
#
#      Uttarakhand    HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0           40.7  30.0  52.5         5.0  ...    70.2        108.2     2.0
# ...

# %%
#выгружаем месяц и год
df[['Day','Month','Year']] = df.Date.str.split('/',expand=True)

# %%
df
# Out:
#                     Date  Punjab  Haryana  Rajasthan  Delhi     UP  \
# 0    02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9
# 1    03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8
# 2    04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7
# 3    05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0
# 4    06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8
# ..                   ...     ...      ...        ...    ...    ...
# 498  01/12/2020 00:00:00   130.8    126.0      220.4   77.3  322.8
# 499  02/12/2020 00:00:00   129.4    127.3      218.4   81.3  331.4
# 500  03/12/2020 00:00:00   132.1    129.7      205.6   85.6  336.7
# 501  04/12/2020 00:00:00   132.1    128.4      207.0   83.9  334.6
# 502  05/12/2020 00:00:00   120.4    111.2      201.4   83.6  287.3
#
#      Uttarakhand    HP   J&K  Chandigarh  ...  Arunachal Pradesh  Assam  \
# 0           40.7  30.0  52.5         5.0  ...                2.1   21.7
# ...

# %%
#загружаем дата сет long_data
long_data = pd.read_csv("https://raw.githubusercontent.com/ilonaSagd/AIilona/main/long_data_.csv",parse_dates=['Dates'])
long_data
# Out:
#           States Regions   latitude  longitude      Dates  Usage
# 0         Punjab      NR  31.519974  75.980003 2019-02-01  119.9
# 1        Haryana      NR  28.450006  77.019991 2019-02-01  130.3
# 2      Rajasthan      NR  26.449999  74.639981 2019-02-01  234.1
# 3          Delhi      NR  28.669993  77.230004 2019-02-01   85.8
# 4             UP      NR  27.599981  78.050006 2019-02-01  313.9
# ...          ...     ...        ...        ...        ...    ...
# 16594    Manipur     NER  24.799971  93.950017 2020-05-12    2.5
# 16595  Meghalaya     NER  25.570492  91.880014 2020-05-12    5.8
# 16596    Mizoram     NER  23.710399  92.720015 2020-05-12    1.6
# 16597   Nagaland     NER  25.666998  94.116570 2020-05-12    2.1
# 16598    Tripura     NER  23.835404  91.279999 2020-05-12    3.3
#
# [16599 rows x 6 columns]

# %%
#определяем среднесуточное потребление энергии городов за исследуемый период
df_by_state = long_data.groupby(['States']).agg({'Usage': ['mean']})
df_by_state
# Out:
#                         Usage
#                          mean
# States
# Andhra Pradesh     176.151889
# Arunachal Pradesh    2.109145
# Assam               24.960040
# Bihar               83.159443
# Chandigarh           4.141551
# Chhattisgarh        83.877137
# DNH                 16.430616
# Delhi               83.380716
# Goa                 11.093241
# Gujarat            323.039563
# HP                  26.568191
# Haryana            138.333598
# J&K                 44.264016
# Jharkhand           23.842545
# Karnataka          204.106759
# Kerala              72.192445
# MP                 208.283101
# Maharashtra        431.570179
# Manipur              2.494632
# Meghalaya            5.643738
# Mizoram              1.706362
# Nagaland             2.162425
# Odisha              80.464612
# Pondy                7.472962
# Punjab             141.145527
# Rajasthan          218.443340
# Sikkim               1.289463
# Tamil Nadu         300.738569
# ...

# %%
#определяем значения по потреблению электроэнергии
df_by_state.plot.bar(legend=False)
plt.title('Потребление энергии городов за период 01.19-12.20г')
plt.ylabel('Cреднесуточное потребление энергии, МВт*ч')
# Out:
# Text(0, 0.5, 'Cреднесуточное потребление энергии, МВт*ч')

# %%
city_data = pd.DataFrame()

for city in ['Punjab','Haryana','Rajasthan','Delhi','UP','Uttarakhand','HP',
            'J&K','Chandigarh','Chhattisgarh','Gujarat','MP','Maharashtra','Goa',
            'DNH','Andhra Pradesh','Telangana','Karnataka','Kerala','Tamil Nadu',
            'Pondy','Bihar','Jharkhand','Odisha','West Bengal','Sikkim',
             'Arunachal Pradesh','Assam','Manipur','Meghalaya','Mizoram','Nagaland','Tripura']:
  city_data[city] = df_dataset_sk[city]

plt.figure(figsize=(50, 6))
sns.boxplot(data=city_data)
plt.xlabel('Город')
plt.ylabel('Значение')
plt.title('Boxplot значений для всех городов')
plt.show()

# %% [markdown]
# Итоги:
# 1.	По графикам датасетов видно, что лидерами максимального потребления электроэнергии являются - Maharashtra, Gujarat, UP
# лидерами минимального потребления электроэнергии - Sikkim, Mizoram, Mizoram.
# 2.	По выгрузке второго датасета видим, что помимо значений первого датасета есть географические координаты каждого города.
# 3.	Объемы потребления электроэнергии в 2019 выше, чем в 2020
