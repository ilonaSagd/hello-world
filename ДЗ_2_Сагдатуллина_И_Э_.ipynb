# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# https://cbr.ru/statistics/bank_sector/   Сведения о рынке ипотечного жилищного кредитования в России

# Среднее значение с 11.2021 по 11.2021 : 510573,00
# Среднее значение с 11.2021 по 11.2022 : 448443,86

# h0 - льготная ипотека увеличит количество выдаваемых кредитов на жилье
# h1 - льготная ипотека не увеличит количество выдаваемых кредитов на жилье

a = 107344.923
b = 156434.615

if ((a * 1.1 - b) < 0.5 or (a * 1.1 - b) > -0.5):
  print ('Гипотеза не отклонена')
else:
  print ('Гипотеза отклонена')
# Out:
# Гипотеза не отклонена
